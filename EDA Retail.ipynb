# %% [markdown]
# # Exploratory Data Analysis on Superstore Data

# %% [markdown]
# ## Objectives:
# #### 1. To perform Exploratory Data Analysis on Superstore Data
# #### 2. Find out business problems and weak areas.
# #### 3. Identify methods to improve profits.

# %% [markdown]
# ### 1. Importing required packages and dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotnine
import warnings
warnings.filterwarnings('ignore')

# %%
Data = pd.read_csv(r'C:\Users\user\Downloads\SampleSuperstore.csv')
# Initial Shape of the Data Frame
Initial_Shape = Data.shape
Initial_Shape
# Out:
# (9994, 13)

# %% [markdown]
# ### 2. Data Inspection

# %%
Data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# No Null-valued cells present.

# %%
Data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### 3. Data Cleaning

# %%
Data.isnull().sum()     #Inspecting for missing values
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
Data.duplicated().sum()      #Finding duplicate values
# Out:
# 17

# %%
Data.drop_duplicates()       #Deleting duplicate values
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ### 4. Data Analysis and Visualisation

# %%
Sales_and_Profits = Data.groupby("Segment").sum().iloc[:,[1,-1]].sum()
round(Sales_and_Profits,2) # Rounding Numericala entries to 2 decimal places
# Out:
# Sales     2297200.86
# Profit     286397.02
# dtype: float64

# %% [markdown]
# Total Sales and Profit in $

# %%
Data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# #### Relational Analysis

# %%
financial = Data.loc[:,['Sales','Quantity','Discount','Profit']]
correlation=financial.corr()
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
covariance=financial.cov()
sns.heatmap(covariance,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
Top_10_Sales = Data.groupby("State").Sales.sum().nlargest(n =10)
plt.style.use('seaborn')
Top_10_Sales.plot(kind ='bar', figsize =(14,8), fontsize =14)
plt.xlabel("States", fontsize =13)
plt.ylabel("Total Sales",fontsize =13)
plt.title("Top 10 States by Sales",fontsize =16)
plt.show()

Top_10_Profits = Data.groupby("State").Profit.sum().nlargest(n =10)
plt.style.use('seaborn')
Top_10_Profits.plot(kind ='bar', figsize =(14,8), fontsize =14)
plt.xlabel("States", fontsize =13)
plt.ylabel("Total Profits",fontsize =13)
plt.title("Top 10 States by Profits",fontsize =16)
plt.show()

# %% [markdown]
# The top states are California followed by New York with a huge margin from other states.

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category', data=Data)
plt.title('Category vs Sub Category')
plt.xlabel('Sub-Catgory')
plt.ylabel('Category')
plt.xticks(rotation=45)
plt.show()

# %%
Data.hist(bins = 50 , figsize = (20,15))
plt.show()

# %%
#Visualise the total repeatable states
plt.figure(figsize=(15,15))
sns.countplot(x=Data['State'])
plt.xticks(rotation=90)
plt.title("STATE")
plt.show()

# %%
Profit_plot = (ggplot(Data, aes(x='Sub-Category', y='Profit', fill='Sub-Category')) + geom_col() + coord_flip()
+ scale_fill_brewer(type='div', palette="Spectral") + theme_classic() + ggtitle('Pie Chart'))

display(Profit_plot)
# Out:
# <ggplot: (136250185981)>

# %% [markdown]
# In the above Pie chart, the profit and loss of each and every subcategories is seen. From graph we can visualize that "binders" sub-category has suffered the highest amount of loss and also the highest profit at the same time amongst all other sub-Categories.
# The next highest profit making sub-category is "Copiers" who have also managed to keep the losses to be the lowest.
# The next highest loss making sub-category is "Tables".

# %%
ggplot(Data, aes(x='Ship Mode', fill = 'Category')) + geom_bar(stat = 'count')
# Out:
# <ggplot: (136241842149)>

# %%
figsize=(15,10)
sns.pairplot(Data,hue='Sub-Category')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
flip_xlabels = theme(axis_text_x = element_text(angle=90, hjust=1),figure_size=(10,5),
                     axis_ticks_length_major=10,axis_ticks_length_minor=5)
(ggplot(Data, aes(x='Sub-Category', fill='Sales')) + geom_bar() + facet_wrap(['Segment']) 
+ flip_xlabels +theme(axis_text_x = element_text(size=12))+ggtitle("Sales From Every Segment Of United States of Whole Data"))
# Out:
# <ggplot: (136249659167)>

# %% [markdown]
# From above Graph we can say that "Home Office" segment has much of the less purchased Sub-Categories and in that "Tables", "Supplies", "Machines", "Copiers", "Bookcases" has the lowest Sales. "Consumer" has the more purchased sub-categories as compared to other segments.

# %%
flip_xlabels = theme(axis_text_x = element_text(angle=90, hjust=1),figure_size=(10,5),
                     axis_ticks_length_major=10,axis_ticks_length_minor=5)
(ggplot(Data, aes(x='Sub-Category', fill='Discount')) + geom_bar() + facet_wrap(['Segment']) 
+ flip_xlabels +theme(axis_text_x = element_text(size=12))+ggtitle("Discount on Categories From Every Segment Of United States of Whole Data"))
# Out:
# <ggplot: (136246628027)>

# %%
flip_xlabels = theme(axis_text_x = element_text(angle=90, hjust=10),figure_size=(10,10),
                     axis_ticks_length_major=50,axis_ticks_length_minor=50)
(ggplot(Data, aes(x='Category', fill='Sales')) + geom_bar() + theme(axis_text_x = element_text(size=10)) 
+ facet_wrap(['Region']) + flip_xlabels+ ggtitle("Sales From Every Region Of United States of Whole Data"))
# Out:
# <ggplot: (136249049417)>

# %%
plt.figure(figsize=(10,4))
sns.lineplot('Discount','Profit', data= Data , color='y',label='Discount')
plt.legend()
plt.show()

# %%
def state_data_viewer(states):
    product_data = Data.groupby(['State'])
    for state in states:
        data = product_data.get_group(state).groupby(['Category'])
        fig, ax = plt.subplots(1, 3, figsize = (28,5))
        fig.suptitle(state, fontsize=14)        
        ax_index = 0
        for cat in ['Furniture', 'Office Supplies', 'Technology']:
            cat_data = data.get_group(cat).groupby(['Sub-Category']).sum()
            sns.barplot(x = cat_data.Profit, y = cat_data.index, ax = ax[ax_index])
            ax[ax_index].set_ylabel(cat)
            ax_index +=1
        fig.show()
states = ['New York','California', 'Washington', 'Mississippi', 'Arizona', 'Texas']
state_data_viewer(states)

# %% [markdown]
# #### K-Means Clustering for Sales vs Profit Analysis for different Sub-categories

# %%
x = Data.iloc[:, [9, 10, 11, 12]].values

from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0).fit(x)
    wcss.append(kmeans.inertia_)
    
sns.set_style("whitegrid") 
sns.FacetGrid(Data, hue ="Sub-Category",height = 6).map(plt.scatter,'Sales','Profit')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()
plt.show()

# %% [markdown]
# From the Above data Visualization and Clustering we can see that in Which states and in which Category Sales and profits are High or less. We can improve in that States By Providing Discounts in prefered Range so that Company and cosumer both will be in profit.

# %% [markdown]
# ### 5. Insights from Data

# %% [markdown]
# #### 5.1. What are total Sales and Profits of the company?

# %% [markdown]
# 1. Total Sales is $2297200.86
#
# 2. Total Profit is $286397.02

# %% [markdown]
# #### 5.2 Distribution of profits across all sub-categories.

# %% [markdown]
# Except "Tables", "Supplies" and "Bookcases", all other sub-categories are in profit.
# Overall all segments are in profit.

# %% [markdown]
# #### 5.3 Region-wise profit distribution.

# %% [markdown]
# The most loss making is due by "Furniture". In central region, there is the most loss while the western and eastern regions have a huge profit.

# %% [markdown]
# #### 5.4 Investigating losses in Furniture category in the Central region

# %% [markdown]
# 1. Losses are inccured in Furniture Cateory irrespective to ship mode.
#
# 2. There is unusually high positive correlation between Postal Code and Discount.
#
# 3. Also, Their is negative correlation between Discount and Sales eventhough dicounts are entered as positive values...i.e. they are not helping in improving sales of "Furniture" category of the company.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# From All these analysis we finally conclude that,
#
# 1) If we give more Discount on products our sales goes increases but Profit get down.
#
# 2) In Technology category business we get more Profit as compared to other two business. This is because we give less discount.
#
# 3) We also focus on our Office Supplies category business because sales of these category is less as compared to other two.
#
# 4) To rise the profits , we first need to sell consumer segment products more .
#
# 5) For enhancing the profits , we need to sell more to the states which are liking our products like NEWYORK and CALIFORNIA .
